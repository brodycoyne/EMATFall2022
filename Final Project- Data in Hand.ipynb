# %% [markdown]
# # Data In Hand
# ## Brody Coyne
# ### 12/2/2022

# %%
import pandas as pd

# %%
nbadata = pd.read_csv("nbadatadec02.csv")

# %%
nbadata
# Out:
#       Rk                   Player Pos  Age   Tm   G  GS    MP    FG   FGA  \
# 0      1              Luka Dončić  PG   23  DAL  20  20  37.6  11.6  22.9
# 1      2             Jayson Tatum  PF   24  BOS  21  21  36.7  10.3  21.1
# 2      3            Stephen Curry  PG   34  GSW  20  20  34.7  10.7  20.7
# 3      4    Giannis Antetokounmpo  PF   28  MIL  17  17  32.8  11.5  21.5
# 4      5  Shai Gilgeous-Alexander  SG   24  OKC  20  20  35.8  10.8  21.3
# ..   ...                      ...  ..  ...  ...  ..  ..   ...   ...   ...
# 269  270          Christian Braun  SG   21  DEN  20   0  13.3   1.2   2.9
# 270  271               Davon Reed  SG   27  DEN  16   1  11.3   0.9   3.1
# 271  272         Josh Christopher  SG   21  HOU  16   0   6.9   1.2   2.8
# 272  273         Matisse Thybulle  SG   25  PHI  18   3  11.6   0.7   2.1
# 273  274              Josh Okogie  SG   24  PHO  18   0   6.2   0.5   1.7
#
#      ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF  PTS▼  Player-additional
# ...

# %% [markdown]
# The data I collected came from the website Basketball Reference, which is one of the most extensive and popular websites for basketball statistics. They allow you to download the data as a .csv file which I opted to do. I then turned that .csv file into a pandas dataframe. The data collected is every player that has played in the NBA so far in the 2022-23 season. It includes things like their name, position, age, team, games played and also includes 22 collected statistics from the season like points scored, total rebounds, steals, turnovers, etc. I decided to collect the per game stats which means all of the statistics are the totals divided by the number of games played.
