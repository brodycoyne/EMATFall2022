# %% [markdown]
# # "Likes" Report
# ## Brody Coyne
# ### 9/20/2022

# %%
import pandas as pd
import json

# %%
with open(r"liked_posts.json") as j:
    ig_dat = json.load(j)

# %% [markdown]
# The company Meta, previously known as Facebook, owns Instagram which means that they are able to collect and store the data. This data was collected for multiple reasons, mainly related to growing the platform and making money, but the two biggest reasons in my opinion are so that they can better curate the platform towards the user's interests and to pair the best advertisements with users.

# %% [markdown]
# This data is reliable because it collects every liked post that the user made. This means that the data should be accurate when analyzed correctly. However, if the data is analyzed incorrectly it could be unreliable.

# %%
ig_dat_df = pd.DataFrame(ig_dat['likes_media_likes'])

# %%
ig_dat_df
# Out:
#                     title media_list_data  \
# 0           bakermayfield              []
# 1            ftblstatpage              []
# 2       thebesthighlights              []
# 3                    cavs              []
# 4                oldspice              []
# 5                     nfl              []
# 6              3jmccollum              []
# 7            sportscenter              []
# 8                 dwxxiii              []
# 9             datboydimez              []
# 10         bleacherreport              []
# 11               nyknicks              []
# 12  kelloggsfrostedflakes              []
# 13           matthewdelly              []
# 14             the.appeal              []
# 15           matthewdelly              []
# 16        underarmournext              []
# 17         bleacherreport              []
# 18        ohiostathletics              []
# 19        quantumgraphics              []
# 20       clevelandrocks02              []
# 21           matthewdelly              []
# 22              culusocks              []
# 23         _dylan_reeves_              []
# 24            slattery_32              []
# 25            slattery_32              []
# 26               vinney01              []
# 27              jawnywynn              []
# 28               patriots              []
# 29              jawnywynn              []
# 30            funny_scnes              []
# 31               patriots              []
# 32               patriots              []
# 33               patriots              []
# 34          mc_creations_              []
#
#                                      string_list_data
# 0   [{'href': 'https://www.instagram.com/p/CGA20y1...
# 1   [{'href': 'https://www.instagram.com/p/B6tlfFl...
# 2   [{'href': 'https://www.instagram.com/tv/B3-qgE...
# 3   [{'href': 'https://www.instagram.com/p/Br7pITu...
# 4   [{'href': 'https://www.instagram.com/p/BoSCavG...
# 5   [{'href': 'https://www.instagram.com/p/BrLFRI_...
# 6   [{'href': 'https://www.instagram.com/p/BopWxYl...
# 7   [{'href': 'https://www.instagram.com/p/Bmdbegc...
# 8   [{'href': 'https://www.instagram.com/p/Bj91VSf...
# 9   [{'href': 'https://www.instagram.com/p/Bj8rBB_...
# 10  [{'href': 'https://www.instagram.com/p/Bi27v1z...
# 11  [{'href': 'https://www.instagram.com/p/BfipO60...
# 12  [{'href': 'https://www.instagram.com/p/BYv1Uny...
# 13  [{'href': 'https://www.instagram.com/p/BRtqYqZ...
# 14  [{'href': 'https://www.instagram.com/p/BExDs1Q...
# 15  [{'href': 'https://www.instagram.com/p/BHkzavU...
# 16  [{'href': 'https://www.instagram.com/p/BHR-itI...
# 17  [{'href': 'https://www.instagram.com/p/BCO_xrd...
# 18  [{'href': 'https://www.instagram.com/p/7srnpvR...
# 19  [{'href': 'https://www.instagram.com/p/2udr75R...
# 20  [{'href': 'https://www.instagram.com/p/1PNJxlH...
# 21  [{'href': 'https://www.instagram.com/p/1i7lfHz...
# 22  [{'href': 'https://www.instagram.com/p/tjcbfKM...
# 23  [{'href': 'https://www.instagram.com/p/tdcMZXN...
# 24  [{'href': 'https://www.instagram.com/p/n8weGfD...
# 25  [{'href': 'https://www.instagram.com/p/n8vmwPj...
# 26  [{'href': 'https://www.instagram.com/p/i48uIQm...
# 27  [{'href': 'https://www.instagram.com/p/aRnUoJE...
# 28  [{'href': 'https://www.instagram.com/p/Z_jctxv...
# 29  [{'href': 'https://www.instagram.com/p/Z1djRnk...
# 30  [{'href': 'https://www.instagram.com/p/ZhAH5iO...
# 31  [{'href': 'https://www.instagram.com/p/ZGw0DWv...
# 32  [{'href': 'https://www.instagram.com/p/YsRkVWv...
# 33  [{'href': 'https://www.instagram.com/p/Yi6qJLP...
# 34  [{'href': 'https://www.instagram.com/p/XNtA3TJ...

# %% [markdown]
# In the previous two code cells I created a DataFrame for my liked posts and then I displayed that DataFrame.

# %%
ig_dat_df['string_list_data'][0][0]['timestamp']
# Out:
# 1603698679

# %%
timestamp = [x[0]['timestamp'] for x in ig_dat_df['string_list_data']]

# %%
ig_dat_df['timestamp'] = timestamp

# %%
ig_dat_df
# Out:
#                     title media_list_data  \
# 0           bakermayfield              []
# 1            ftblstatpage              []
# 2       thebesthighlights              []
# 3                    cavs              []
# 4                oldspice              []
# 5                     nfl              []
# 6              3jmccollum              []
# 7            sportscenter              []
# 8                 dwxxiii              []
# 9             datboydimez              []
# 10         bleacherreport              []
# 11               nyknicks              []
# 12  kelloggsfrostedflakes              []
# 13           matthewdelly              []
# 14             the.appeal              []
# 15           matthewdelly              []
# 16        underarmournext              []
# 17         bleacherreport              []
# 18        ohiostathletics              []
# 19        quantumgraphics              []
# 20       clevelandrocks02              []
# 21           matthewdelly              []
# 22              culusocks              []
# 23         _dylan_reeves_              []
# 24            slattery_32              []
# 25            slattery_32              []
# 26               vinney01              []
# 27              jawnywynn              []
# 28               patriots              []
# 29              jawnywynn              []
# 30            funny_scnes              []
# 31               patriots              []
# 32               patriots              []
# 33               patriots              []
# 34          mc_creations_              []
#
#                                      string_list_data   timestamp
# 0   [{'href': 'https://www.instagram.com/p/CGA20y1...  1603698679
# 1   [{'href': 'https://www.instagram.com/p/B6tlfFl...  1577821093
# 2   [{'href': 'https://www.instagram.com/tv/B3-qgE...  1571915932
# 3   [{'href': 'https://www.instagram.com/p/Br7pITu...  1546028916
# 4   [{'href': 'https://www.instagram.com/p/BoSCavG...  1544392513
# 5   [{'href': 'https://www.instagram.com/p/BrLFRI_...  1544392309
# 6   [{'href': 'https://www.instagram.com/p/BopWxYl...  1538946323
# 7   [{'href': 'https://www.instagram.com/p/Bmdbegc...  1534363731
# 8   [{'href': 'https://www.instagram.com/p/Bj91VSf...  1528926640
# 9   [{'href': 'https://www.instagram.com/p/Bj8rBB_...  1528921438
# 10  [{'href': 'https://www.instagram.com/p/Bi27v1z...  1526517853
# 11  [{'href': 'https://www.instagram.com/p/BfipO60...  1519417353
# 12  [{'href': 'https://www.instagram.com/p/BYv1Uny...  1505331749
# 13  [{'href': 'https://www.instagram.com/p/BRtqYqZ...  1489704637
# 14  [{'href': 'https://www.instagram.com/p/BExDs1Q...  1468492350
# 15  [{'href': 'https://www.instagram.com/p/BHkzavU...  1467951995
# 16  [{'href': 'https://www.instagram.com/p/BHR-itI...  1467346956
# 17  [{'href': 'https://www.instagram.com/p/BCO_xrd...  1456460851
# 18  [{'href': 'https://www.instagram.com/p/7srnpvR...  1442449116
# 19  [{'href': 'https://www.instagram.com/p/2udr75R...  1432568374
# 20  [{'href': 'https://www.instagram.com/p/1PNJxlH...  1429209556
# 21  [{'href': 'https://www.instagram.com/p/1i7lfHz...  1429209139
# 22  [{'href': 'https://www.instagram.com/p/tjcbfKM...  1412105475
# 23  [{'href': 'https://www.instagram.com/p/tdcMZXN...  1411844662
# 24  [{'href': 'https://www.instagram.com/p/n8weGfD...  1400020759
# 25  [{'href': 'https://www.instagram.com/p/n8vmwPj...  1400020757
# 26  [{'href': 'https://www.instagram.com/p/i48uIQm...  1389151997
# 27  [{'href': 'https://www.instagram.com/p/aRnUoJE...  1370664016
# 28  [{'href': 'https://www.instagram.com/p/Z_jctxv...  1370041761
# 29  [{'href': 'https://www.instagram.com/p/Z1djRnk...  1369701354
# 30  [{'href': 'https://www.instagram.com/p/ZhAH5iO...  1369048271
# 31  [{'href': 'https://www.instagram.com/p/ZGw0DWv...  1368136178
# 32  [{'href': 'https://www.instagram.com/p/YsRkVWv...  1367262829
# 33  [{'href': 'https://www.instagram.com/p/Yi6qJLP...  1366945287
# 34  [{'href': 'https://www.instagram.com/p/XNtA3TJ...  1364681007

# %% [markdown]
# In the previous code cells I pulled out the timestamp from the list data and then added an extra column that added the timestamp and connected them to the likes.

# %%
ig_dat_df.groupby('title').count().sort_values('title', ascending=False)
# Out:
#                        media_list_data  string_list_data  timestamp
# title
# vinney01                             1                 1          1
# underarmournext                      1                 1          1
# thebesthighlights                    1                 1          1
# the.appeal                           1                 1          1
# sportscenter                         1                 1          1
# slattery_32                          2                 2          2
# quantumgraphics                      1                 1          1
# patriots                             4                 4          4
# oldspice                             1                 1          1
# ohiostathletics                      1                 1          1
# nyknicks                             1                 1          1
# nfl                                  1                 1          1
# mc_creations_                        1                 1          1
# matthewdelly                         3                 3          3
# kelloggsfrostedflakes                1                 1          1
# jawnywynn                            2                 2          2
# funny_scnes                          1                 1          1
# ftblstatpage                         1                 1          1
# dwxxiii                              1                 1          1
# datboydimez                          1                 1          1
# culusocks                            1                 1          1
# clevelandrocks02                     1                 1          1
# cavs                                 1                 1          1
# bleacherreport                       2                 2          2
# bakermayfield                        1                 1          1
# _dylan_reeves_                       1                 1          1
# 3jmccollum                           1                 1          1

# %% [markdown]
# In the previous code cell I sorted the data with the "groupby" and "count" functions to display the number of likes for each account.

# %% [markdown]
# Hypothesis:If I click all of the ads that appear in my Instagram feed how will that influence the data that they collect and how they choose to advertise to me?
# -I was inspired to create this hypothesis when I saw the data file titled "ads_interests." When looking through the data collected I was suprised by what the data said and how much was collected. If I could have access to data that was not part of the downloaded Instagram data, the best type of data would be how Instagram groups certain interests and advertisements together so that I can completely understand why Instagram chooses the ads for me that they do.
